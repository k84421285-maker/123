# %%
import pandas as pd
from scipy import stats
import numpy as np

# %%
df = pd.read_csv("/content/sample_data/california_housing_test.csv")
x = df["total_rooms"].dropna()

# %%
result = stats.ttest_1samp(x, popmean=30, alternative="less")

# %%
mean_x = x.mean()
n = len(x)

# %%
se = stats.sem(x)
ci_low, ci_high = stats.t.interval(0.95, df=n-1, loc=mean_x, scale=se)

# %%
print("표본평균:", mean_x)
print("t-statistic:", result.statistic)
print("p-value:", result.pvalue)
print("95% CI:", (ci_low, ci_high))
# Out:
# 표본평균: 2599.578666666667
# t-statistic: 65.29135984828908
# p-value: 1.0
# 95% CI: (np.float64(2522.4120239364465), np.float64(2676.745309396887))
