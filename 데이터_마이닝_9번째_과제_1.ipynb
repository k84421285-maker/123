# %%
from pathlib import Path
import pandas as pd
from scipy.stats import chi2_contingency

# %%
DATA_DIR = Path('/content/type3')
file_path = DATA_DIR / 'channel_purchase.csv'

# %%
df = pd.read_csv(file_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2199/2618208116.py in <cell line: 0>()
# ----> 1 df = pd.read_csv(file_path)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/type3/channel_purchase.csv'

# %%
print('[데이터 상위 5행]')
print(df.head(), '\n')

print('[변수 정보]')
print(df.info(), '\n')
# Out:
# [데이터 상위 5행]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2199/3304057250.py in <cell line: 0>()
#       1 print('[데이터 상위 5행]')
# ----> 2 print(df.head(), '\n')
#       3
#       4 print('[변수 정보]')
#       5 print(df.info(), '\n')
#
# NameError: name 'df' is not defined

# %%
table = pd.crosstab(df['channel'], df['purchase_yn'])

print('[교차표]')
print(table, '\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2199/587073681.py in <cell line: 0>()
# ----> 1 table = pd.crosstab(df['channel'], df['purchase_yn'])
#       2
#       3 print('[교차표]')
#       4 print(table, '\n')
#
# NameError: name 'df' is not defined

# %%
chi2, p, dof, expected = chi2_contingency(table)

print('[검정 결과]')
print('chi-square statistic:', round(chi2, 4))
print('p-value:', round(p, 6))
print('degrees of freedom:', dof)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2199/1724653072.py in <cell line: 0>()
# ----> 1 chi2, p, dof, expected = chi2_contingency(table)
#       2
#       3 print('[검정 결과]')
#       4 print('chi-square statistic:', round(chi2, 4))
#       5 print('p-value:', round(p, 6))
#
# NameError: name 'table' is not defined

# %%
expected_df = pd.DataFrame(expected, index=table.index, columns=table.columns)

print('\n[기대도수]')
print(expected_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2199/3810032011.py in <cell line: 0>()
# ----> 1 expected_df = pd.DataFrame(expected, index=table.index, columns=table.columns)
#       2
#       3 print('\n[기대도수]')
#       4 print(expected_df)
#
# NameError: name 'expected' is not defined

# %%
conversion_rate = df.groupby('channel')['purchase_yn'].mean().sort_values(ascending=False) * 100

print('\n[채널별 구매전환율(%)]')
print(conversion_rate.round(2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2199/2425179066.py in <cell line: 0>()
# ----> 1 conversion_rate = df.groupby('channel')['purchase_yn'].mean().sort_values(ascending=False) * 100
#       2
#       3 print('\n[채널별 구매전환율(%)]')
#       4 print(conversion_rate.round(2))
#
# NameError: name 'df' is not defined

# %%
print('\n[해석]')
if p < 0.05:
    print('p-value가 0.05보다 작으므로, 유입채널과 구매여부는 독립이 아니며 서로 관련이 있다고 해석할 수 있습니다.')
else:
    print('p-value가 0.05 이상이므로, 유입채널과 구매여부의 관련성을 확인하기 어렵습니다.')

print(f'가장 높은 구매전환율 채널은 {conversion_rate.index[0]}이며, 전환율은 {conversion_rate.iloc[0]:.2f}%입니다.')
# Out:
# [해석]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2199/2738762279.py in <cell line: 0>()
#       1 print('\n[해석]')
# ----> 2 if p < 0.05:
#       3     print('p-value가 0.05보다 작으므로, 유입채널과 구매여부는 독립이 아니며 서로 관련이 있다고 해석할 수 있습니다.')
#       4 else:
#       5     print('p-value가 0.05 이상이므로, 유입채널과 구매여부의 관련성을 확인하기 어렵습니다.')
#
# NameError: name 'p' is not defined
