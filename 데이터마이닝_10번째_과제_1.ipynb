# %%
from google.colab import drive
from pathlib import Path
import pandas as pd
import statsmodels.formula.api as smf

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_DIR = Path('/content/type3')
file_path = DATA_DIR / 'retail_sales_reg1.csv'

# %%
df = pd.read_csv(file_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1895/2618208116.py in <cell line: 0>()
# ----> 1 df = pd.read_csv(file_path)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/type3/retail_sales_reg1.csv'

# %%
print('[데이터 상위 5행]')
print(df.head(), '\n')

print('[기본 정보]')
print(df.info(), '\n')
# Out:
# [데이터 상위 5행]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1895/3412430675.py in <cell line: 0>()
#       1 print('[데이터 상위 5행]')
# ----> 2 print(df.head(), '\n')
#       3
#       4 print('[기본 정보]')
#       5 print(df.info(), '\n')
#
# NameError: name 'df' is not defined

# %%
model = smf.ols('sales ~ ad_cost + staff + event_cnt', data=df).fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1895/2750225067.py in <cell line: 0>()
# ----> 1 model = smf.ols('sales ~ ad_cost + staff + event_cnt', data=df).fit()
#
# NameError: name 'df' is not defined

# %%
print('[회귀 요약 결과]')
print(model.summary())
# Out:
# [회귀 요약 결과]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1895/2704411190.py in <cell line: 0>()
#       1 print('[회귀 요약 결과]')
# ----> 2 print(model.summary())
#
# NameError: name 'model' is not defined

# %%
print('\n[회귀계수]')
print(model.params)

print('\n[p-value]')
print(model.pvalues)

print('\n[R-squared]')
print(model.rsquared)
# Out:
# [회귀계수]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1895/2495179356.py in <cell line: 0>()
#       1 print('\n[회귀계수]')
# ----> 2 print(model.params)
#       3
#       4 print('\n[p-value]')
#       5 print(model.pvalues)
#
# NameError: name 'model' is not defined

# %%
beta_ad = model.params['ad_cost']
print('\n광고비 10단위 증가 시 예상 매출 변화:', beta_ad * 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1895/2994763672.py in <cell line: 0>()
# ----> 1 beta_ad = model.params['ad_cost']
#       2 print('\n광고비 10단위 증가 시 예상 매출 변화:', beta_ad * 10)
#
# NameError: name 'model' is not defined

# %%
sig_vars = model.pvalues[model.pvalues < 0.05].index.tolist()
print('\n유의한 변수:', sig_vars)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1895/3265549839.py in <cell line: 0>()
# ----> 1 sig_vars = model.pvalues[model.pvalues < 0.05].index.tolist()
#       2 print('\n유의한 변수:', sig_vars)
#
# NameError: name 'model' is not defined
